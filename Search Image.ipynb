# %%
import search as s
import importlib

# %%
# Cat_008.jpg
# Cat_009.jpg
# Dog_020.jpg
# Dog_001.jpg
# Dog_005.jpg

importlib.reload(s)
s.img_search_normal("Cat_001.jpg")
# Out:
# 161
# Search Score = 28.0592
# Search Score = 28.0639
# Search Score = 28.7989

# %%
s.img_search_frcnn("Cat_001.jpg")
# Out:
# 226
# Search Score = 20.1472
# Search Score = 20.8086
# Search Score = 21.4651

# %%
s.img_search_caption("Cat_001.jpg")

# %%
s.img_search_combined("Cat_001.jpg")
